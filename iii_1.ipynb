# %%
# !pip install hdfs

# %%
from hdfs import *

# %%
client = Client('http://master:50070')

# %%
#查看hdfs的根目錄
client.list('/')
# Out:
# ['data', 'hive', 'iii-bigdata', 'tmp', 'user']

# %%
#建立目錄
client.makedirs('/iii')
client.makedirs('/iii', permission = 777 )

# %%
#更改名稱
client.rename('/iii','/iii-bigdata')

# %%
#資料下載放到hdfs目錄下
# !wget https://raw.githubusercontent.com/orozcohsu/iii_20201128/main/Superstore-2019.csv -O /tmp/Superstore-2019.csv
client.upload('/iii-bigdata/Superstore_2019/Superstore_2019.csv', '/tmp/Superstore-2019.csv')
# Out:
# --2020-11-26 14:43:48--  https://raw.githubusercontent.com/orozcohsu/iii_20201128/main/Superstore-2019.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.108.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2447844 (2.3M) [text/plain]
# Saving to: ‘/tmp/Superstore-2019.csv’
#
# /tmp/Superstore-201 100%[===================>]   2.33M   520KB/s    in 4.1s
#
# 2020-11-26 14:43:53 (588 KB/s) - ‘/tmp/Superstore-2019.csv’ saved [2447844/2447844]
# '/iii-bigdata/Superstore_2019/Superstore_2019.csv'

# %%
#查看
client.list('/iii-bigdata')
# Out:
# ['Starbucks_Store.csv', 'Superstore_2019.csv']
